# %%
try:
    print(a)
except :
    print("error")
# Out:
# error

# %%
# WAP to Enter a number to print square if no number is entered then a keyboard inrupt is generated

try:
    n = int(input("Enter Number: "))
except KeyboardInterrupt:
    print("error")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 # WAP to Enter a number to prin square if no number is entered then a keyboard inrupt is generated
#       3 try:
# ----> 4     n = int(input("Enter Number: "))
#       5 except KeyboardInterrupt:
#       6     print("error")
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# WAP to enter a no if no positive or 0 print else raise exception

# %%
try:
    x = int(input("Enter a number: "))
    print("You entered:", x)
except ValueError:
    print("Invalid input! Please enter an integer.")
# Out:
# Invalid input! Please enter an integer.

# %%
try:
    x = int(input("Enter a number: "))
    y = 10 / x
except ValueError:
    print("Please enter a valid integer.")
except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Cannot divide by zero.

# %%
try:
    x = int(input("Enter a number: "))
    y = 10 / x
except Exception as e:
    print("Error occurred:", e)
# Out:
# Error occurred: invalid literal for int() with base 10: 'v'

# %%
class NegativeNumberError(Exception):
    pass

x = -10
if x < 0:
    raise NegativeNumberError("Negative number not allowed")
# Out:
# ---------------------------------------------------------------------------
# NegativeNumberError                       Traceback (most recent call last)
# Cell In[5], line 6
#       4 x = -10
#       5 if x < 0:
# ----> 6     raise NegativeNumberError("Negative number not allowed")
#
# NegativeNumberError: Negative number not allowed

# %%
try:
    x = int(input("Enter a number: "))
    y = 10 / x
except (ValueError, ZeroDivisionError) as e:
    print("Error:", e)
# Out:
# Error: division by zero

# %%
try:
    f = open("file.txt", "r")
    content = f.read()
except FileNotFoundError:
    print("File not found!")
finally:
    print("Execution completed.")
# Out:
# File not found!
# Execution completed.
