# %% [markdown]
# 1st September

# %% [markdown]
# # Strings

# %% [markdown]
# ## concatenation

# %%
# Concatination
print("Good '+' Morning")
print("Good" + "Morning")
# Out:
# Good '+' Morning
# GoodMorning

# %%
print("Python" + )
# Out:
#   Cell In[46], line 1
#     print("Python" + )
#                      ^
# SyntaxError: invalid syntax

# %%
print("Python" + 3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 print("Python" + 3.5)
#
# TypeError: can only concatenate str (not "float") to str

# %%
print("Python" + "3.5")
# Out:
# Python3.5

# %%
print("12" + "34")
print(1234)
# Out:
# 1234
# 1234

# %% [markdown]
# ## Multiplication

# %%
print("Good"*5)
# Out:
# GoodGoodGoodGoodGood

# %%
print(5*"Good")
# Out:
# GoodGoodGoodGoodGood

# %%
print("Good"*"5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print("Good"*"5")
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print("Good"*5.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 print("Good"*5.0)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ##  Slicing

# %%
s = "python is Easy!!!"

# %%
print(s)
# Out:
# python is Easy!!!

# %%
print(s[0])
print(s[3:9])
print(s[4:])
print(s[-1])
print(s[:5])
# Out:
# p
# hon is
# on is Easy!!!
# !
# pytho

# %%
'''Unicode is a std way of writing text, python has unicode text editor, prefixing strings with 'u' or 'U'
Python allows you to specify unicode text.'''
# Out:
# "Unicode is a std way of writing text, python has unicode text editor, prefixing strings with 'u' or 'U'\nPython allows you to specify unicode text."

# %%
print("What's your name?")
# print('What's your name?')    This will give error so to solve such errors we will use escape Sequence
print('What\'s your name?')
# Out:
# What's your name?
# What's your name?

# %%
''' Escape sequence is a combination of characters that is translated to another character or sequence of characters that may be difficult or impossible to represent directly'''
# Out:
# ' Escape seq is a combination of characters that is translated to another character or sequence of characters that may be difficult or impossible to represent directly'

# %%
print("The boy replies, "My name is Aaditya."")
# Out:
#   Cell In[64], line 1
#     print("The boy replies, "My name is Aaditya."")
#                              ^
# SyntaxError: invalid syntax

# %%
print("The boy replies, \"My name is Aaditya.\"")
# Out:
# The boy replies, "My name is Aaditya."

# %%
print("The boy replies,\n\"My name is Aaditya.\"")
# Out:
# The boy replies,
# "My name is Aaditya."

# %%
print("The boy replies,\t\"My name is Aaditya.\"")
# Out:
# The boy replies,	"My name is Aaditya."

# %%
print("The boy replies,\ \"My name is Aaditya.\"")

# when specifying a string with single '\' at end of line is added it indicate string is continued in next line but no new line is added otherwise
# Out:
# The boy replies,\ "My name is Aaditya."

# %%
print("\\")
print("\'")
print("\"")
print("Hello\n world" )
print("Hello \t world")
print("\056")
print("\x2E")
print("\x87")   # It gives Blank space
# Out:
# \
# '
# "
# Hello
#  world
# Hello 	 world
# .
# .
# 

# %% [markdown]
# # Number System

# %%
''' 11011 to decimal
51 to octal
360 octal to decimal
51 to hexadecimal
33 hex to decimal '''
# Out:
# ' 11011 to decimal\n51 to octal\n360 to decimal\n51 to hexadecimal\n33 hex to decimal '

# %%
# decimal to binary
int('11011' ,2)
# Out:
# 27

# %%
oct(51)
# Out:
# '0o63'

# %%
int('360', 8)
# Out:
# 240

# %%
hex(51)
# Out:
# '0x33'

# %%
int('33', 6)
# Out:
# 21

# %% [markdown]
# # BITWISE OPERATORS

# %%
# AND
print(110 and 10)
# Out:
# 10

# %%
# OR
print(110 or 000)
# Out:
# 110

# %%
# NOT
print(not False)
# Out:
# True

# %%
# XOR
print(111 ^ 1)
# Out:
# 110

# %%
# RIGHT SHIFT
print( 101 >> 2)
# Out:
# 25

# %%
# LEFT SHIFT
print( 101 << 2)
# Out:
# 404

# %% [markdown]
# # Identity

# %%
# (is) or (is not)

# %%
x = [1,2]
y = [1, 2]

print("x is y", x is y)
# Out:
# x is y False

# %%
z = x
print(x is z)
# Out:
# True

# %%
x1 = 5
y1 =5

x2 = "hello"
y2= 'hello'

x3 = [1, 2, 3]
y3 = [1, 2, 3]

print(x1 is not y1)
print(x2 is y2)
print(x3 is y3)
# Out:
# False
# True
# False

# %%
message = 'HELLO WORLD'
dict = {1:'a', 2:'b'}
# Out:
# b

# %%
# check if x is present if message
'x' in message
# Out:
# False

# %%
'HELLO' in message
# Out:
# True

# %%
'hello' in message
# Out:
# False

# %%
1 in dict.keys()
# Out:
# True

# %%
print('a' in dict.values())
'a' in dict
# Out:
# True
# False

# %%
# TERNARY operator

10 if 10 < 20 else 20
# Out:
# 10

# %%
x = 5
'+ve' if x > 0 else "-ve"
# Out:
# '+ve'

# %% [markdown]
# # Precedence and assoiciativity

# %%
# !ls
# Out:
# Lab2.ipynb  Lab_1.ipynb

# %%
10 + 20*30
# Out:
# 610

# %%
(40+20)*30/10
# Out:
# 180.0

# %%
40+(20*30)/10
# Out:
# 100.0

# %%
False == False or True
# Out:
# True

# %%
False == (False or True)
# Out:
# False

# %%
100/10*10
# Out:
# 100.0

# %%
# construct if else block which rus if when lucnh is either fruit or sandwitch and only if money if more than or equal to 2

lunch = input("Enter Your lunch type: ")     
money = int(input("Enter amount of money you have: "))
if (lunch == "fruit" or lunch == "sandwich") and money >= 2:
    print("You can buy lunch.")
else:
    print("Cannot buy lunch.")
# Out:
# You can buy lunch.
