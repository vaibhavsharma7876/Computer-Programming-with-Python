# %%
# Lambda function to square a number

num = int(input("Enter a number: "))

square = lambda x: x * x

print("Square of the number:", square(num))
# Out:
# Enter a number:  4
# Square of the number: 16

# %%
# Recursive function to count digits

def count_digits(n):
    if n == 0:
        return 0
    return 1 + count_digits(n // 10)

num = int(input("Enter a positive integer: "))

if num == 0:
    print("Number of digits: 1")
else:
    print("Number of digits:", count_digits(num))
# Out:
# Enter a positive integer:  268
# Number of digits: 3

# %%
# List input and reverse printing without built-in methods

n = int(input("Enter number of elements: "))
numbers = []

for i in range(n):
    value = int(input(f"Enter element {i+1}: "))
    numbers.append(value)

print("Original List:", numbers)

print("Reversed List:", end=" ")
for i in range(len(numbers) - 1, -1, -1):
    print(numbers[i], end=" ")
# Out:
# Enter number of elements:  4
# Enter element 1:  1
# Enter element 2:  2
# Enter element 3:  6
# Enter element 4:  8
# Original List: [1, 2, 6, 8]
# Reversed List: 8 6 2 1
