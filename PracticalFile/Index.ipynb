# %% [markdown]
# # Python Programming Lab - Practical Record

# %% [markdown]
# ### Name    : Vaibhav Sharma
# ### Roll No. : 25901339
# ### Institution NIT Jalandhar
# ### Department Centre for Artificial Intelligence
#
# Repository: [GitHub](https://github.com/vaibhavsharma7876/Computer-Programming-with-Python/tree/main/PracticalFile)

# %% [markdown]
# | **Experiment No.** | **Experiment Name**                                                                                               | **Date** |
# | ------------------ | ----------------------------------------------------------------------------------------------------------------- | ------------------ |
# | 1                  | Installation and Basic Programs (Variables and Data Types, Arithmetic, Comparison, Assignment, Logical Operators) | **25/08/2025**     |
# | 2                  | Operators Based Programs                                                                                          | **01/09/2025**     |
# | 3                  | String Manipulation, Number System and Conversions                                                                | **08/09/2025**     |
# | 4                  | Operator Precedence, Conditional Statements, Loops (For and While)                                                | **15/09/2025**     |
# | 5                  | Nested Loops, Keyword Arguments                                                                                   | **22/09/2025**     |
# | 6                  | Programs Based on Functions                                                                                       | **27/09/2025**     |
# | 7                  | Modules and Packages                                                                                              | **29/09/2025**     |
# | 8                  | String and Its Operations                                                                                         | **13/10/2025**     |
# | 9                  | File Handling                                                                                                     | **27/10/2025**     |
# | 10                 | Data Structures: Lists, Tuples, Sets                                                                              | **03/11/2025**     |
# | 11                 | Programming Exercises with Classes and Objects, Inheritance                                                       | **10/11/2025**     |
# | 12                 | Operator Overloading and Error Handling                                                                           | **17/11/2025**     |
